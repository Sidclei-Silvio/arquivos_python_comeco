# %%
import pandas as pd

# URL do arquivo CSV do dataset da FIFA
url = "https://raw.githubusercontent.com/amanthedorkknight/fifa18-all-player-statistics/master/2019/data.csv"

# Baixar o arquivo CSV e criar o DataFrame
try:
    df_fifa = pd.read_csv(url)
    print("DataFrame da FIFA baixado com sucesso!")
    
except Exception as e:
    print("Erro ao baixar o DataFrame da FIFA:", e)
# Out:
# DataFrame da FIFA baixado com sucesso!

# %%
df_brasileiros_real_madrid = df_fifa.loc[(df_fifa["Nationality"] == "Brazil") & (df_fifa["Club"] == "Real Madrid")]

# %%
df_brasileiros_real_madrid.head()
# Out:
#       Unnamed: 0      ID             Name  Age  \
# 27            27  200145         Casemiro   26
# 35            35  176676          Marcelo   30
# 1143        1143  238794  Vinícius Júnior   17
#
#                                                Photo Nationality  \
# 27    https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 35    https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 1143  https://cdn.sofifa.org/players/4/19/238794.png      Brazil
#
#                                      Flag  Overall  Potential         Club  \
# 27    https://cdn.sofifa.org/flags/54.png       88         90  Real Madrid
# 35    https://cdn.sofifa.org/flags/54.png       88         88  Real Madrid
# 1143  https://cdn.sofifa.org/flags/54.png       77         92  Real Madrid
#
#       ... Composure Marking StandingTackle  SlidingTackle GKDiving  \
# 27    ...      84.0    88.0           90.0           87.0     13.0
# 35    ...      86.0    71.0           85.0           86.0     12.0
# ...

# %%
df_fifa[['Name', 'Age', 'Photo']]
# Out:
#                      Name  Age                                           Photo
# 0                L. Messi   31  https://cdn.sofifa.org/players/4/19/158023.png
# 1       Cristiano Ronaldo   33   https://cdn.sofifa.org/players/4/19/20801.png
# 2               Neymar Jr   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3                  De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4            K. De Bruyne   27  https://cdn.sofifa.org/players/4/19/192985.png
# ...                   ...  ...                                             ...
# 18202        J. Lundstram   19  https://cdn.sofifa.org/players/4/19/238813.png
# 18203  N. Christoffersson   19  https://cdn.sofifa.org/players/4/19/243165.png
# 18204           B. Worman   16  https://cdn.sofifa.org/players/4/19/241638.png
# 18205      D. Walker-Rice   17  https://cdn.sofifa.org/players/4/19/246268.png
# 18206           G. Nugent   16  https://cdn.sofifa.org/players/4/19/246269.png
#
# ...
